# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
""" My Lane as an ML Task

I selected the **Content Performance Prediction** lane.

This is primarily a **classification** problem. The goal is to classify whether a webpage is likely to perform well or not based on historical search and content features.

Machine learning is suitable because many factors influence page performance, making it difficult to create accurate fixed rules. """
# Out:
# ' My Lane as an ML Task\n\nI selected the **Content Performance Prediction** lane.\n\nThis is primarily a **classification** problem. The goal is to classify whether a webpage is likely to perform well or not based on historical search and content features.\n\nMachine learning is suitable because many factors influence page performance, making it difficult to create accurate fixed rules. '

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
## Target or Proxy

""" The target is whether a webpage performs well.

Since the dataset does not contain a direct performance label, I will use a proxy such as high CTR or high traffic to represent successful content.

Example:
- High CTR = Successful page
- Low CTR = Needs improvement """
# Out:
# ' The target is whether a webpage performs well.\n\nSince the dataset does not contain a direct performance label, I will use a proxy such as high CTR or high traffic to represent successful content.\n\nExample:\n- High CTR = Successful page\n- Low CTR = Needs improvement '

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
## Success Metric

""" The main success metric is Accuracy.

I will also consider Precision, Recall, and F1-score because correctly identifying high-performing webpages is more important than simply maximizing overall accuracy."""
# Out:
# ' The main success metric is Accuracy.\n\nI will also consider Precision, Recall, and F1-score because correctly identifying high-performing webpages is more important than simply maximizing overall accuracy.'

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("./data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)
display(df.head())

print("One row represents one webpage (content item).")
# Out:
# Dataset Shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
## Why ML Beats a Fixed Rule

""" A fixed rule cannot accurately predict webpage performance because many features such as search volume, competition, CTR, impressions, and engagement interact with each other.

Machine learning can learn these complex patterns from historical data and provide better predictions than a simple if-else rule.

The prediction helps the content team decide which webpages should be optimized first. """
# Out:
# ' A fixed rule cannot accurately predict webpage performance because many features such as search volume, competition, CTR, impressions, and engagement interact with each other.\n\nMachine learning can learn these complex patterns from historical data and provide better predictions than a simple if-else rule.\n\nThe prediction helps the content team decide which webpages should be optimized first. '

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
